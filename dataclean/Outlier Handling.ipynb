# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('https://github.com/dashbikash/datasets/raw/refs/heads/main/Diabetes.csv')
df.head()
# Out:
#    pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 0            6      148         72       35        0  33.6  0.627   50
# 1            1       85         66       29        0  26.6  0.351   31
# 2            8      183         64        0        0  23.3  0.672   32
# 3            1       89         66       23       94  28.1  0.167   21
# 4            0      137         40       35      168  43.1  2.288   33
#
#    diabetes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1

# %%
df.dtypes['bmi']
# Out:
# dtype('float64')

# %%
sns.boxplot(df['bmi'])
# Out:
# <Axes: ylabel='bmi'>

# %%
sns.boxplot(df['dpf'])
# Out:
# <Axes: ylabel='dpf'>

# %%
sns.violinplot(df["bmi"])
# Out:
# <Axes: ylabel='bmi'>

# %%
from scipy.stats import zscore

# %%
df['z_score'] = zscore(df['bmi'])

# %%
sns.boxplot(df['transformed'])
# Out:
# <Axes: ylabel='transformed'>

# %%
threshold = 3
outlier_mask = df['z_score'].abs() > threshold

# %%
import numpy as np

df['transformed'] = df['bmi']  # start with original values
df.loc[outlier_mask, 'transformed'] = df.loc[outlier_mask, 'bmi'].apply(np.log)
